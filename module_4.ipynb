# %%
import zoo
zoo.hours()
# Out:
# Open 9-5 daily

# %%
import zoo as menagerie
menagerie.hours()
# Out:
# Open 9-5 daily

# %%
import sqlite3

conn = sqlite3.connect('books.db')
curs = conn.cursor()
curs.execute('''CREATE TABLE books
    (title TEXT, author TEXT, year INT)''')
conn.commit()
conn.close()

# %%
import csv
import sqlite3

conn = sqlite3.connect('books.db')
curs = conn.cursor()

with open ('books2.csv', 'rt') as fin:
    reader = csv.DictReader(fin)
    for row in reader:
        curs.execute('INSERT INTO books (title, author, year) VALUES (?, ?, ?)',
                     (row['title'], row['author'], int(row['year'])))

conn.commit()
conn.close()

# %%
import sqlalchemy

conn = sqlalchemy.create_engine('sqlite:///books.db')

with conn.connect() as connection:
    output = connection.execute(sqlalchemy.text('SELECT title FROM books ORDER BY title'))
    for title in output.fetchall():
        print(title)
# Out:
# ('Perdido Street Station',)
# ('Small Gods',)
# ('The Spellman Files',)
# ('The Weirdstone of Brisingamen',)
# ('Thud!',)
